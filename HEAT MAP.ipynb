# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data =  pd.read_csv("given.csv", index_col=0)

# %%
data
# Out:
#          gene_0    gene_1    gene_2     gene_3     gene_4  gene_5     gene_6  \
# Class
# PRAD   0.000000  2.017209  3.265527   5.478487  10.431999       0   7.175175
# LUAD   0.000000  0.592732  1.588421   7.586157   9.623011       0   6.816049
# PRAD   0.000000  3.511759  4.327199   6.881787   9.870730       0   6.972130
# PRAD   0.000000  3.663618  4.507649   6.659068  10.196184       0   7.843375
# BRCA   0.000000  2.655741  2.821547   6.539454   9.738265       0   6.566967
# PRAD   0.000000  3.467853  3.581918   6.620243   9.706829       0   7.758510
# KIRC   0.000000  1.224966  1.691177   6.572007   9.640511       0   6.754888
# PRAD   0.000000  2.854853  1.750478   7.226720   9.758691       0   5.952103
# BRCA   0.000000  3.992125  2.772730   6.546692  10.488252       0   7.690222
# PRAD   0.000000  3.642494  4.423558   6.849511   9.464466       0   7.947216
# BRCA   0.000000  3.492071  3.553373   7.151707  10.253446       0   8.301258
# ...

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data,cmap='coolwarm')
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
#visualising correlations

# %%
well_data  = pd.read_csv("given.csv")

# %%
well_data
# Out:
#    Class    gene_0    gene_1    gene_2     gene_3     gene_4  gene_5  \
# 0   PRAD  0.000000  2.017209  3.265527   5.478487  10.431999       0
# 1   LUAD  0.000000  0.592732  1.588421   7.586157   9.623011       0
# 2   PRAD  0.000000  3.511759  4.327199   6.881787   9.870730       0
# 3   PRAD  0.000000  3.663618  4.507649   6.659068  10.196184       0
# 4   BRCA  0.000000  2.655741  2.821547   6.539454   9.738265       0
# 5   PRAD  0.000000  3.467853  3.581918   6.620243   9.706829       0
# 6   KIRC  0.000000  1.224966  1.691177   6.572007   9.640511       0
# 7   PRAD  0.000000  2.854853  1.750478   7.226720   9.758691       0
# 8   BRCA  0.000000  3.992125  2.772730   6.546692  10.488252       0
# 9   PRAD  0.000000  3.642494  4.423558   6.849511   9.464466       0
# 10  BRCA  0.000000  3.492071  3.553373   7.151707  10.253446       0
# 11  KIRC  0.000000  2.941181  2.663276   6.561690   9.376293       0
# 12  PRAD  0.000000  3.970348  2.364292   7.145443   9.240605       0
# ...

# %%
corr = well_data.corr()

# %%
corr
# Out:
#            gene_0    gene_1    gene_2    gene_3    gene_4  gene_5    gene_6  \
# gene_0   1.000000  0.125222  0.378084 -0.176726 -0.302192     NaN  0.200040
# gene_1   0.125222  1.000000  0.587764  0.180446 -0.225747     NaN  0.146907
# gene_2   0.378084  0.587764  1.000000  0.134629 -0.007761     NaN  0.395288
# gene_3  -0.176726  0.180446  0.134629  1.000000  0.078996     NaN  0.022353
# gene_4  -0.302192 -0.225747 -0.007761  0.078996  1.000000     NaN -0.117007
# gene_5        NaN       NaN       NaN       NaN       NaN     NaN       NaN
# gene_6   0.200040  0.146907  0.395288  0.022353 -0.117007     NaN  1.000000
# gene_7   0.381486  0.317905  0.304532 -0.197684 -0.493934     NaN  0.451935
# gene_8        NaN       NaN       NaN       NaN       NaN     NaN       NaN
# gene_9  -0.031833  0.136233 -0.055711 -0.042542  0.196667     NaN  0.053269
# gene_10 -0.068273  0.092266  0.035241  0.082591 -0.220682     NaN  0.257735
# ...

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr,cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr,cmap='RdBu',vmin=-1,vmax=1,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (25,18))
sns.heatmap(corr,cmap='magma',vmin=-1,vmax=1,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (35,28))
sns.heatmap(corr,cmap='magma',vmin=-1,vmax=1,annot=True,)
# Out:
# <AxesSubplot:>

# %%
# Example arrays (replace these with your actual data)
heatmap = np.array([[0.8, 0.2, 0.6], [0.4, 0.9, 0.3], [0.5, 0.7, 0.1]])
ground_truth = np.array([[1, 0, 1], [0, 1, 0], [0, 1, 0]])

# %%
# Define a threshold
threshold = 0.5

# %%
# Threshold the heatmap to create binary predictions
predicted = (heatmap >= threshold).astype(int)

# %%
# Calculate TP, FP, TN, FN
TP = np.sum((predicted == 1) & (ground_truth == 1))
FP = np.sum((predicted == 1) & (ground_truth == 0))
TN = np.sum((predicted == 0) & (ground_truth == 0))
FN = np.sum((predicted == 0) & (ground_truth == 1))

# %%
# Calculate accuracy
accuracy = (TP + TN) / (TP + TN + FP + FN)

# %%
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8888888888888888

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('given.csv')

# %%
data.head()
# Out:
#   Class  gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# 0  PRAD     0.0  2.017209  3.265527  5.478487  10.431999       0  7.175175
# 1  LUAD     0.0  0.592732  1.588421  7.586157   9.623011       0  6.816049
# 2  PRAD     0.0  3.511759  4.327199  6.881787   9.870730       0  6.972130
# 3  PRAD     0.0  3.663618  4.507649  6.659068  10.196184       0  7.843375
# 4  BRCA     0.0  2.655741  2.821547  6.539454   9.738265       0  6.566967
#
#      gene_7  gene_8  ...   gene_21    gene_22  gene_23   gene_24   gene_25  \
# 0  0.591871       0  ...  0.000000   9.796088        0  0.000000  1.598651
# 1  0.000000       0  ...  0.000000  10.070470        0  0.000000  0.000000
# 2  0.452595       0  ...  3.660427   8.970920        0  0.000000  0.796598
# 3  0.434882       0  ...  0.000000   8.524616        0  0.000000  0.000000
# 4  0.360982       0  ...  0.000000   8.047238        0  1.435949  0.000000
#
#     gene_26    gene_27   gene_28   gene_29  gene_30
# ...

# %%
# Data Preprocessing
# Separate features and target
X = data.drop(columns=['Class'])
y = data['Class']

# %%
# Encode the target variable
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=)

# %%
# Train a logistic regression classifier
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predict the labels on the test set
y_pred = classifier.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7142857142857143
