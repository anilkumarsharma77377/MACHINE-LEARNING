# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris['data'][:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
data = iris.data
species = iris.target
species_labels = iris.target_names

# %%
pca = PCA(n_components = 2)

# %%
pca.fit(data)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ],
#        [ 0.65658877,  0.73016143, -0.17337266, -0.07548102]])

# %%
Z = pca.fit_transform(data)

# %%
Z.shape
# Out:
# (150, 2)

# %%
df = pd.DataFrame(z, columns=['PCA1'])  # Use a single column name
df['species'] = species  # Add the 'Species' column

# %%
columns = ['PCA1','PCA2']

# %%
df = pd.DataFrame(Z, columns=['PCA1', 'PCA2'])

# %%
df['species']= species

# %%
# Plot the PCA scatter plot
plt.figure(figsize=(10, 7))
scatter = plt.scatter(df['PCA1'], df['PCA2'], c=df['species'], cmap=plt.cm.get_cmap('viridis', 3))
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('PCA Scatter Plot')

# Add species labels
for i, label in enumerate(species_labels):
    species_points = df[df['species'] == i]
    plt.text(species_points['PCA1'].mean(), species_points['PCA2'].mean(), label, 
             fontsize=12, ha='center', va='center', 
             bbox=dict(facecolor='white', alpha=0.6, edgecolor='none'))

# Add colorbar to indicate the species
cbar = plt.colorbar(scatter, ticks=[0, 1, 2])
cbar.ax.set_yticklabels(species_labels)

plt.show()

# %%
pca = PCA (n_components = 1)

# %%
pca.fit(data)
# Out:
# PCA(n_components=1)

# %%
pca_components = pca.transform(x)

# %%
species_label = ['setosa','Versicolor','Virginica']

# %%
z = pca.fit_transform(data)

# %%
plt.scatter(z[:,0],z[:,0],cmap = plt.cm.get_cmap('viridis',3))
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('PCA Scatter Plot')
# Out:
# Text(0.5, 1.0, 'PCA Scatter Plot')
